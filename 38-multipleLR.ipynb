# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_regression
import plotly.express as px
import plotly.graph_objects as go
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
X,y = make_regression(n_samples=100 , n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
# make dataframe 
df = pd.DataFrame(X, columns=['x1', 'x2'])
df['y'] = y
print(df.shape , df.isnull().sum())
df.head()
# Out:
# (100, 3) x1    0
# x2    0
# y     0
# dtype: int64
#          x1        x2          y
# 0 -0.143064 -0.661981   8.038552
# 1  0.917771 -0.741525 -47.288205
# 2  0.324423 -0.668248 -35.132183
# 3 -1.408273  0.433701  48.840550
# 4 -0.087327 -0.366185  13.717939

# %%
fig = px.scatter_3d(df , x='x1',y='x2',z='y')
fig.show()

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(df.drop('y' , axis=1),df['y'],test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
lr.score(X_test , y_test)
# Out:
# 0.7057526963983298

# %%
lr.coef_
# Out:
# array([ 2.31152264, 51.83679476])

# %%
lr.intercept_
# Out:
# np.float64(-10.182493872640906)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# MAE 33.022483455135564
# MSE 1713.949323148669
# R2 score 0.7057526963983298
