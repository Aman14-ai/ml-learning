# %%
import pandas as pd;
import requests;

# %%
response  = requests.get("https://api.themoviedb.org/3/discover/movie?api_key=8aeea0eca819e1deb50ab85647a6655b&include_adult=true&include_video=false&language=en-US&page=3&sort_by=popularity.desc")

# %%
response.json()
# Out:
# {'page': 3,
#  'results': [{'adult': True,
#    'backdrop_path': '/m8ecW8Nausc28uUmLF9Uw3JtfzZ.jpg',
#    'genre_ids': [99],
#    'id': 1304758,
#    'original_language': 'ja',
#    'original_title': '超大型新人NO.1STYLE 白上咲花 AVデビュー',
#    'overview': "S1 NO.1 STYLE changes today.  2024 - A super new star appears.  The most orthodox beautiful girl star of this century in the adult industry.  Her looks. Her clarity. Her smile. Her slender and beautiful tall figure.  A 'perfect' existence.  A genius AV idol is born.  Everything about her seems perfect.  However, she also has a childish side, playing innocently and enjoying herself innocently.  She eats gyoza with a smile.  Everyone smiles when they're with her.  This 20-year-old girl is sensitive when sexual intercourse begins. Her trembling reaction while still tense is erotic. Colorless and transparent, Shirakami Emika. AV DEBUT",
#    'popularity': 92.63,
#    'poster_path': '/piVUtWLQL4hfaoB22NTGdJXRaOD.jpg',
# ...

# %%
response.json()['results']
# Out:
# [{'adult': True,
#   'backdrop_path': '/m8ecW8Nausc28uUmLF9Uw3JtfzZ.jpg',
#   'genre_ids': [99],
#   'id': 1304758,
#   'original_language': 'ja',
#   'original_title': '超大型新人NO.1STYLE 白上咲花 AVデビュー',
#   'overview': "S1 NO.1 STYLE changes today.  2024 - A super new star appears.  The most orthodox beautiful girl star of this century in the adult industry.  Her looks. Her clarity. Her smile. Her slender and beautiful tall figure.  A 'perfect' existence.  A genius AV idol is born.  Everything about her seems perfect.  However, she also has a childish side, playing innocently and enjoying herself innocently.  She eats gyoza with a smile.  Everyone smiles when they're with her.  This 20-year-old girl is sensitive when sexual intercourse begins. Her trembling reaction while still tense is erotic. Colorless and transparent, Shirakami Emika. AV DEBUT",
#   'popularity': 92.63,
#   'poster_path': '/piVUtWLQL4hfaoB22NTGdJXRaOD.jpg',
#   'release_date': '2024-04-24',
# ...

# %%
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path     genre_ids       id  \
# 0   True  /m8ecW8Nausc28uUmLF9Uw3JtfzZ.jpg          [99]  1304758
# 1  False  /sItIskd5xpiE64bBWYwZintkGf3.jpg  [28, 53, 80]   541671
#
#   original_language              original_title  \
# 0                ja  超大型新人NO.1STYLE 白上咲花 AVデビュー
# 1                en                   Ballerina
#
#                                             overview  popularity  \
# 0  S1 NO.1 STYLE changes today.  2024 - A super n...     92.6300
# 1  Taking place during the events of John Wick: C...     91.0674
#
#                         poster_path release_date  \
# 0  /piVUtWLQL4hfaoB22NTGdJXRaOD.jpg   2024-04-24
# 1  /lIpIFzENkZEOStamt76U3JRc0nC.jpg   2025-06-04
#
#                                                title  video  vote_average  \
# 0  Super Large Newcomer NO.1STYLE Sakura Shirakam...  False        10.000
# 1                                          Ballerina  False         7.404
#
#    vote_count
# 0           2
# ...

# %%
import time
import pandas as pd
import requests

API_KEY = "8aeea0eca819e1deb50ab85647a6655b"
all_results = []

for i in range(1, 101):
    url = f"https://api.themoviedb.org/3/discover/movie?api_key={API_KEY}&include_adult=true&include_video=false&language=en-US&page={i}&sort_by=popularity.desc"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()  # raises HTTPError if bad response
        all_results.extend(response.json().get('results', []))
    except requests.exceptions.RequestException as e:
        print(f"Error on page {i}: {e}")
        break
    time.sleep(0.3)  # wait 300ms per request (safe)

df = pd.DataFrame(all_results)
print(df.shape)


df.head(2)
# Out:
# Error on page 7: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# (120, 14)
#    adult                     backdrop_path  genre_ids       id  \
# 0  False  /iZLqwEwUViJdSkGVjePGhxYzbDb.jpg  [878, 53]   755898
# 1  False  /mEW9XMgYDO6U0MJcIRqRuSwjzN5.jpg   [28, 53]  1007734
#
#   original_language     original_title  \
# 0                en  War of the Worlds
# 1                en           Nobody 2
#
#                                             overview  popularity  \
# 0  Will Radford is a top analyst for Homeland Sec...    698.1919
# 1  Former assassin Hutch Mansell takes his family...    432.6555
#
#                         poster_path release_date              title  video  \
# 0  /yvirUYrva23IudARHn3mMGVxWqM.jpg   2025-07-29  War of the Worlds  False
# 1  /svXVRoRSu6zzFtCzkRsjZS7Lqpd.jpg   2025-08-13           Nobody 2  False
#
#    vote_average  vote_count
# 0         4.328         476
# ...

# %%
df.to_csv('movies.csv',index=False)
