# %%
from ydata_profiling import ProfileReport
import pandas as pd;

# %%
df = pd.read_csv("train.csv")

# %%
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)
profile.to_file("titanic_report.html")
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 613.88it/s]00:00, 29.50it/s, Describe variable: Embarked]
# Summarize dataset: 100%|██████████| 47/47 [00:02<00:00, 21.47it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:02<00:00,  2.36s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 64.76it/s]
